# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from tensorflow.keras.layers import Dense, Input, InputLayer, Flatten
from tensorflow.keras.models import Sequential, Model
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# Check if GPU is mounted
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import random

#Load Building folders to display and check dir

plt.figure(figsize=(20,20))

building_folder='natural_scene_data/seg_train/seg_train/buildings/'

#Randomly display 5 house out of building folder
for i in range(5):
    file = random.choice(os.listdir(building_folder))
    image_path= os.path.join(building_folder, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %%
# Displaying Random 5 Beautiful Sea
sea_folder='natural_scene_data/seg_train/seg_train/sea/'
plt.figure(figsize=(20,20))
#Randomly display 5 house out of building folder
for i in range(5):
    file = random.choice(os.listdir(sea_folder))
    image_path= os.path.join(sea_folder, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %%
IMG_WIDTH=200 # Later function to resize image
IMG_HEIGHT=200

# Create final dir for 5 folder of datasets, building, forest etc...
test_image_folder='natural_scene_data/seg_train/seg_train/'

# %%
# Function to easily process and create desired dataset
def create_dataset(img_folder):
   
    img_data_array=[]
    class_name=[] # To append Classname
   
    for dir1 in os.listdir(img_folder):
        for file in os.listdir(os.path.join(img_folder, dir1)):
       
            image_path= os.path.join(img_folder, dir1,  file)
            image= cv2.imread( image_path, cv2.COLOR_BGR2RGB)
            image=cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH),interpolation = cv2.INTER_AREA)
            image=np.array(image)
            image = image.astype('float32')
            image /= 255 
            img_data_array.append(image)
            class_name.append(dir1)
    return img_data_array, class_name
# extract the image array and class name


img_data, class_name =create_dataset(test_image_folder)

# %%
# Generating class label dictionary later to map into Y_train dataset
class_dict={k: v for v, k in enumerate(np.unique(class_name))}
class_dict
# Out:
# {'buildings': 0,
#  'forest': 1,
#  'glacier': 2,
#  'mountain': 3,
#  'sea': 4,
#  'street': 5}

# %%
# Map the Y train set with dictionary class above
target_val=  [class_dict[class_name[i]] for i in range(len(class_name))]
len(target_val)
# Out:
# 14034

# %%
def unique(list1):
    x = np.array(list1)
    print(np.unique(x))
    
unique(target_val) # Check if the label mapping is correct
# Out:
# [0 1 2 3 4 5]

# %%
# Creating the CNN Model
#CNN SELECTED because its nature best for image classification
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# Conv2d high filter to less filter architecture
model = Sequential()
model.add(Conv2D(32,(3, 3), activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3), padding='valid')) #Input shape 3 represent BGR?
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(16,(3, 3), activation='relu', padding='valid'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output Layer
model.add(Dense(6, activation='softmax')) # Softmax selected for class > 2

# %%
img_data = np.array(img_data, np.float32)
target_val = np.array(list(map(int,target_val)), np.float32) # Target value is an array, need convert to np float 32

# %%
# Convert X train set
#img_data = np.array(img_data, np.float32)
#target_val = np.array(list(map(int,target_val)), np.float32) # Target value is an array, need convert to np float 32


#model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#history = model.fit(x=img_data, y=target_val, epochs=10, batch_size=32)

# %%
# Validation

validate_image_folder='natural_scene_data/seg_test/seg_test/'

validate_img_data, validate_class_name =create_dataset(validate_image_folder)

# %%
val_class_dict={k: v for v, k in enumerate(np.unique(validate_class_name))}
val_class_dict
# Out:
# {'buildings': 0,
#  'forest': 1,
#  'glacier': 2,
#  'mountain': 3,
#  'sea': 4,
#  'street': 5}

# %%
validate_target_val=  [val_class_dict[validate_class_name[i]] for i in range(len(validate_class_name))]
len(validate_target_val)
# Out:
# 3000

# %%
validate_img_data = np.array(validate_img_data, np.float32)
validate_target_val = np.array(list(map(int,validate_target_val)), np.float32) # Target value is an array, need convert to np float 32

# %%
unique(validate_target_val) # Check if the label mapping is correct
# Out:
# [0. 1. 2. 3. 4. 5.]

# %%
from tensorflow.keras.layers import Dropout, BatchNormalization

model2 = Sequential()
model2.add(Conv2D(16,(3, 3), activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3), padding='valid')) #Input shape 3 represent BGR?
model2.add(MaxPooling2D((2,2)))
model2.add(Conv2D(32,(3, 3), activation='relu', padding='valid'))
model2.add(MaxPooling2D((2,2)))
model2.add(BatchNormalization(momentum=0.9))
model2.add(Conv2D(64,(3, 3), activation='relu', padding='valid'))
model2.add(MaxPooling2D((2,2)))
model2.add(Flatten())
model2.add(Dense(256, activation='relu'))
model2.add(BatchNormalization(momentum=0.9))
model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.5))
model2.add(Dense(64, activation='relu'))
model2.add(Dense(32, activation='relu'))
model2.add(Dropout(0.5))

# Output Layer
model2.add(Dense(6, activation='softmax')) # Softmax selected for class > 2

# %%
# Customer optimizer
adam_custom_lr = keras.optimizers.Adam(learning_rate=0.001)

# Early stopping since optimizer learning rate is super low
from tensorflow.keras import callbacks
early_stopping = callbacks.EarlyStopping(monitor ="val_accuracy", 
                                        patience = 10, 
                                        restore_best_weights = True)

model2.compile(loss='sparse_categorical_crossentropy', optimizer=adam_custom_lr, metrics=['accuracy'])
history = model2.fit(x=img_data, y=target_val, epochs=200, batch_size=32, validation_data=(validate_img_data, validate_target_val), callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 439/439 [==============================] - 27s 41ms/step - loss: 1.2220 - accuracy: 0.5270 - val_loss: 0.8145 - val_accuracy: 0.7020
# Epoch 2/200
# 439/439 [==============================] - 15s 34ms/step - loss: 0.8999 - accuracy: 0.6835 - val_loss: 1.1496 - val_accuracy: 0.6067
# Epoch 3/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.7518 - accuracy: 0.7448 - val_loss: 0.6329 - val_accuracy: 0.7773
# Epoch 4/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.6395 - accuracy: 0.7865 - val_loss: 0.6194 - val_accuracy: 0.7810
# Epoch 5/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.5658 - accuracy: 0.8125 - val_loss: 0.7696 - val_accuracy: 0.7237
# Epoch 6/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.4734 - accuracy: 0.8500 - val_loss: 0.6015 - val_accuracy: 0.8093
# Epoch 7/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.3930 - accuracy: 0.8765 - val_loss: 0.6582 - val_accuracy: 0.8107
# Epoch 8/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.4743 - accuracy: 0.8424 - val_loss: 0.8007 - val_accuracy: 0.7413
# Epoch 9/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.3287 - accuracy: 0.8977 - val_loss: 0.7368 - val_accuracy: 0.7950
# Epoch 10/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.2299 - accuracy: 0.9305 - val_loss: 0.8082 - val_accuracy: 0.7940
# Epoch 11/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.1873 - accuracy: 0.9476 - val_loss: 0.8537 - val_accuracy: 0.8077
# Epoch 12/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.1549 - accuracy: 0.9573 - val_loss: 0.9669 - val_accuracy: 0.8020
# Epoch 13/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.1520 - accuracy: 0.9557 - val_loss: 1.0811 - val_accuracy: 0.7810
# Epoch 14/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.1482 - accuracy: 0.9582 - val_loss: 1.0484 - val_accuracy: 0.7813
# Epoch 15/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.1757 - accuracy: 0.9493 - val_loss: 1.0267 - val_accuracy: 0.7810
# Epoch 16/200
# 439/439 [==============================] - 15s 35ms/step - loss: 0.1802 - accuracy: 0.9490 - val_loss: 1.1543 - val_accuracy: 0.7780
# Epoch 17/200
# 439/439 [==============================] - 16s 35ms/step - loss: 0.1172 - accuracy: 0.9649 - val_loss: 1.3416 - val_accuracy: 0.7897

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 198, 198, 16)      448
#
#  max_pooling2d_2 (MaxPooling  (None, 99, 99, 16)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 97, 97, 32)        4640
#
#  max_pooling2d_3 (MaxPooling  (None, 48, 48, 32)       0
#  2D)
#
#  batch_normalization (BatchN  (None, 48, 48, 32)       128
#  ormalization)
#
#  conv2d_4 (Conv2D)           (None, 46, 46, 64)        18496
#
#  max_pooling2d_4 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  flatten_1 (Flatten)         (None, 33856)             0
#
#  dense_3 (Dense)             (None, 256)               8667392
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dense_4 (Dense)             (None, 128)               32896
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_5 (Dense)             (None, 64)                8256
#
#  dense_6 (Dense)             (None, 32)                2080
#
#  dropout_1 (Dropout)         (None, 32)                0
#
#  dense_7 (Dense)             (None, 6)                 198
#
# =================================================================
# Total params: 8,735,558
# Trainable params: 8,734,982
# Non-trainable params: 576
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

acc2 = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss2 = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc2)+1)

plt.plot(epochs, acc2, 'b', label='Train Accuracy')
plt.plot(epochs, val_acc, 'r', label='Test Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss2, 'b', label='Train Loss')
plt.plot(epochs, val_loss, 'r', label='Test Loss')
plt.legend()
plt.show()
