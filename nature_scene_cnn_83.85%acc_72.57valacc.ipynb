# %%
import pandas as pd
import numpy as np
import os
import tensorflow as tf
import cv2
from tensorflow import keras
from tensorflow.keras.layers import Dense, Input, InputLayer, Flatten
from tensorflow.keras.models import Sequential, Model
from  matplotlib import pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline

# Check if GPU is mounted
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import random

#Load Building folders to display and check dir

plt.figure(figsize=(20,20))

building_folder='natural_scene_data/seg_train/seg_train/buildings/'

#Randomly display 5 house out of building folder
for i in range(5):
    file = random.choice(os.listdir(building_folder))
    image_path= os.path.join(building_folder, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %%
# Displaying Random 5 Beautiful Sea
sea_folder='natural_scene_data/seg_train/seg_train/sea/'
plt.figure(figsize=(20,20))
#Randomly display 5 house out of building folder
for i in range(5):
    file = random.choice(os.listdir(sea_folder))
    image_path= os.path.join(sea_folder, file)
    img=mpimg.imread(image_path)
    ax=plt.subplot(1,5,i+1)
    ax.title.set_text(file)
    plt.imshow(img)

# %%
IMG_WIDTH=200 # Later function to resize image
IMG_HEIGHT=200

# Create final dir for 5 folder of datasets, building, forest etc...
test_image_folder='natural_scene_data/seg_train/seg_train/'

# %%
# Function to easily process and create desired dataset
def create_dataset(img_folder):
   
    img_data_array=[]
    class_name=[] # To append Classname
   
    for dir1 in os.listdir(img_folder):
        for file in os.listdir(os.path.join(img_folder, dir1)):
       
            image_path= os.path.join(img_folder, dir1,  file)
            image= cv2.imread( image_path, cv2.COLOR_BGR2RGB)
            image=cv2.resize(image, (IMG_HEIGHT, IMG_WIDTH),interpolation = cv2.INTER_AREA)
            image=np.array(image)
            image = image.astype('float32')
            image /= 255 
            img_data_array.append(image)
            class_name.append(dir1)
    return img_data_array, class_name
# extract the image array and class name


img_data, class_name =create_dataset(test_image_folder)

# %%
# Generating class label dictionary later to map into Y_train dataset
class_dict={k: v for v, k in enumerate(np.unique(class_name))}
class_dict
# Out:
# {'buildings': 0,
#  'forest': 1,
#  'glacier': 2,
#  'mountain': 3,
#  'sea': 4,
#  'street': 5}

# %%
# Map the Y train set with dictionary class above
target_val=  [class_dict[class_name[i]] for i in range(len(class_name))]
len(target_val)
# Out:
# 14034

# %%
def unique(list1):
    x = np.array(list1)
    print(np.unique(x))
    
unique(target_val) # Check if the label mapping is correct
# Out:
# [0 1 2 3 4 5]

# %%
# Creating the CNN Model
#CNN SELECTED because its nature best for image classification
from tensorflow.keras.layers import Conv2D, MaxPooling2D

# Conv2d high filter to less filter architecture
model = Sequential()
model.add(Conv2D(32,(3, 3), activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3), padding='valid')) #Input shape 3 represent BGR?
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(16,(3, 3), activation='relu', padding='valid'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(32, activation='relu'))
model.add(Dense(16, activation='relu'))

# Output Layer
model.add(Dense(6, activation='softmax')) # Softmax selected for class > 2

# %%
img_data = np.array(img_data, np.float32)
target_val = np.array(list(map(int,target_val)), np.float32) # Target value is an array, need convert to np float 32

# %%
print(img_data.shape)
print(target_val.shape)
# Out:
# (14034, 200, 200, 3)
# (14034,)

# %%
target_val
# Out:
# array([0., 0., 0., ..., 5., 5., 5.], dtype=float32)

# %%
# Convert X train set
#img_data = np.array(img_data, np.float32)
#target_val = np.array(list(map(int,target_val)), np.float32) # Target value is an array, need convert to np float 32


#model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
#history = model.fit(x=img_data, y=target_val, epochs=10, batch_size=32)

# %%
# Validation

validate_image_folder='natural_scene_data/seg_test/seg_test/'

validate_img_data, validate_class_name =create_dataset(validate_image_folder)

# %%
val_class_dict={k: v for v, k in enumerate(np.unique(validate_class_name))}
val_class_dict
# Out:
# {'buildings': 0,
#  'forest': 1,
#  'glacier': 2,
#  'mountain': 3,
#  'sea': 4,
#  'street': 5}

# %%
validate_target_val=  [val_class_dict[validate_class_name[i]] for i in range(len(validate_class_name))]
len(validate_target_val)
# Out:
# 3000

# %%
validate_img_data = np.array(validate_img_data, np.float32)
validate_target_val = np.array(list(map(int,validate_target_val)), np.float32) # Target value is an array, need convert to np float 32

# %%
unique(validate_target_val) # Check if the label mapping is correct
# Out:
# [0. 1. 2. 3. 4. 5.]

# %%
from tensorflow.keras.layers import Dropout, BatchNormalization

model2 = Sequential()
model2.add(Conv2D(32,(3, 3), activation='relu', input_shape=(IMG_WIDTH, IMG_HEIGHT, 3), padding='valid')) #Input shape 3 represent BGR?
model2.add(MaxPooling2D((2,2)))
model2.add(Conv2D(64,(3, 3), activation='relu', padding='valid'))
model2.add(MaxPooling2D((2,2)))
model2.add(BatchNormalization(momentum=0.9))
#model2.add(Conv2D(64,(3, 3), activation='relu', padding='valid'))
#model2.add(MaxPooling2D((2,2)))
model2.add(Flatten())
#model2.add(Dense(256, activation='relu'))
#model2.add(BatchNormalization(momentum=0.9))
#model2.add(Dense(128, activation='relu'))
model2.add(Dropout(0.3))
model2.add(Dense(64, activation='relu'))
model2.add(Dropout(0.3))
model2.add(Dense(32, activation='relu'))
model2.add(Dropout(0.3))
model2.add(Dense(16, activation='relu'))
model2.add(Dropout(0.5))

# Output Layer
model2.add(Dense(6, activation='softmax')) # Softmax selected for class > 2

# %%
# Customer optimizer
adam_custom_lr = keras.optimizers.Adam(learning_rate=0.01)

# Early stopping since optimizer learning rate is super low
from tensorflow.keras import callbacks
early_stopping = callbacks.EarlyStopping(monitor ="val_accuracy", 
                                        patience = 10, 
                                        restore_best_weights = True)

model2.compile(loss='sparse_categorical_crossentropy', optimizer=adam_custom_lr, metrics=['accuracy'])
history = model2.fit(x=img_data, y=target_val, epochs=200, batch_size=32, validation_data=(validate_img_data, validate_target_val), callbacks=[early_stopping])
# Out:
# Epoch 1/200
# 439/439 [==============================] - 33s 55ms/step - loss: 1.7529 - accuracy: 0.3016 - val_loss: 1.4632 - val_accuracy: 0.4140
# Epoch 2/200
# 439/439 [==============================] - 20s 45ms/step - loss: 1.4194 - accuracy: 0.3966 - val_loss: 1.1632 - val_accuracy: 0.5377
# Epoch 3/200
# 439/439 [==============================] - 20s 45ms/step - loss: 1.3346 - accuracy: 0.4250 - val_loss: 1.1317 - val_accuracy: 0.5077
# Epoch 4/200
# 439/439 [==============================] - 20s 45ms/step - loss: 1.2697 - accuracy: 0.4482 - val_loss: 1.0452 - val_accuracy: 0.5393
# Epoch 5/200
# 439/439 [==============================] - 20s 45ms/step - loss: 1.1701 - accuracy: 0.5044 - val_loss: 1.0844 - val_accuracy: 0.5740
# Epoch 6/200
# 439/439 [==============================] - 19s 44ms/step - loss: 1.1251 - accuracy: 0.5276 - val_loss: 1.0837 - val_accuracy: 0.5703
# Epoch 7/200
# 439/439 [==============================] - 20s 46ms/step - loss: 1.0721 - accuracy: 0.5458 - val_loss: 1.1124 - val_accuracy: 0.5437
# Epoch 8/200
# 439/439 [==============================] - 19s 44ms/step - loss: 1.0026 - accuracy: 0.5747 - val_loss: 0.9007 - val_accuracy: 0.6163
# Epoch 9/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.9773 - accuracy: 0.5915 - val_loss: 1.1704 - val_accuracy: 0.5957
# Epoch 10/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.9533 - accuracy: 0.6057 - val_loss: 0.8857 - val_accuracy: 0.6543
# Epoch 11/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.9042 - accuracy: 0.6152 - val_loss: 1.2083 - val_accuracy: 0.5823
# Epoch 12/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.8726 - accuracy: 0.6318 - val_loss: 0.9166 - val_accuracy: 0.6507
# Epoch 13/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.8446 - accuracy: 0.6472 - val_loss: 0.8926 - val_accuracy: 0.6407
# Epoch 14/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.8237 - accuracy: 0.6489 - val_loss: 0.9334 - val_accuracy: 0.6300
# Epoch 15/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.8119 - accuracy: 0.6599 - val_loss: 0.9500 - val_accuracy: 0.6590
# Epoch 16/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.7714 - accuracy: 0.6748 - val_loss: 0.9228 - val_accuracy: 0.6770
# Epoch 17/200
# 439/439 [==============================] - 20s 46ms/step - loss: 0.7764 - accuracy: 0.6781 - val_loss: 0.9401 - val_accuracy: 0.6513
# Epoch 18/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.7407 - accuracy: 0.6898 - val_loss: 0.8774 - val_accuracy: 0.6740
# Epoch 19/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.7350 - accuracy: 0.6925 - val_loss: 0.9236 - val_accuracy: 0.6670
# Epoch 20/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.7103 - accuracy: 0.7074 - val_loss: 0.9375 - val_accuracy: 0.6690
# Epoch 21/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.6747 - accuracy: 0.7170 - val_loss: 0.9848 - val_accuracy: 0.6767
# Epoch 22/200
# 439/439 [==============================] - 20s 45ms/step - loss: 0.6870 - accuracy: 0.7175 - val_loss: 0.9000 - val_accuracy: 0.6750
# Epoch 23/200
# 439/439 [==============================] - 20s 45ms/step - loss: 0.6774 - accuracy: 0.7160 - val_loss: 1.0127 - val_accuracy: 0.6850
# Epoch 24/200
# 439/439 [==============================] - 19s 43ms/step - loss: 0.6598 - accuracy: 0.7230 - val_loss: 1.0469 - val_accuracy: 0.6547
# Epoch 25/200
# 439/439 [==============================] - 19s 43ms/step - loss: 0.6527 - accuracy: 0.7284 - val_loss: 1.1113 - val_accuracy: 0.6710
# Epoch 26/200
# 439/439 [==============================] - 19s 43ms/step - loss: 0.6515 - accuracy: 0.7329 - val_loss: 1.0344 - val_accuracy: 0.6587
# Epoch 27/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.6154 - accuracy: 0.7431 - val_loss: 1.1157 - val_accuracy: 0.6973
# Epoch 28/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.6429 - accuracy: 0.7331 - val_loss: 1.1968 - val_accuracy: 0.6857
# Epoch 29/200
# 439/439 [==============================] - 19s 43ms/step - loss: 0.6190 - accuracy: 0.7523 - val_loss: 1.0718 - val_accuracy: 0.6957
# Epoch 30/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.5969 - accuracy: 0.7531 - val_loss: 1.0574 - val_accuracy: 0.7007
# Epoch 31/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.5937 - accuracy: 0.7592 - val_loss: 1.0553 - val_accuracy: 0.6940
# Epoch 32/200
# 439/439 [==============================] - 19s 43ms/step - loss: 0.5590 - accuracy: 0.7874 - val_loss: 1.0188 - val_accuracy: 0.7103
# Epoch 33/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.5719 - accuracy: 0.7836 - val_loss: 1.1238 - val_accuracy: 0.6980
# Epoch 34/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.5824 - accuracy: 0.7836 - val_loss: 1.1581 - val_accuracy: 0.7100
# Epoch 35/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.5450 - accuracy: 0.7989 - val_loss: 1.1760 - val_accuracy: 0.7167
# Epoch 36/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.5235 - accuracy: 0.8050 - val_loss: 1.0516 - val_accuracy: 0.7137
# Epoch 37/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.5428 - accuracy: 0.8055 - val_loss: 1.1785 - val_accuracy: 0.6903
# Epoch 38/200
# 439/439 [==============================] - 19s 44ms/step - loss: 0.5308 - accuracy: 0.8063 - val_loss: 1.3634 - val_accuracy: 0.5670
# Epoch 39/200
# 439/439 [==============================] - 18s 42ms/step - loss: 0.5372 - accuracy: 0.8043 - val_loss: 0.9881 - val_accuracy: 0.6710
# Epoch 40/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.5151 - accuracy: 0.8091 - val_loss: 1.1149 - val_accuracy: 0.7073
# Epoch 41/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.5075 - accuracy: 0.8127 - val_loss: 1.2633 - val_accuracy: 0.7100
# Epoch 42/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.5178 - accuracy: 0.8144 - val_loss: 1.3652 - val_accuracy: 0.7260
# Epoch 43/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.5570 - accuracy: 0.8070 - val_loss: 1.1902 - val_accuracy: 0.7227
# Epoch 44/200
# 439/439 [==============================] - 18s 42ms/step - loss: 0.4872 - accuracy: 0.8225 - val_loss: 1.2644 - val_accuracy: 0.7207
# Epoch 45/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4850 - accuracy: 0.8260 - val_loss: 1.3453 - val_accuracy: 0.7170
# Epoch 46/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4731 - accuracy: 0.8321 - val_loss: 1.3057 - val_accuracy: 0.6947
# Epoch 47/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4627 - accuracy: 0.8323 - val_loss: 1.5435 - val_accuracy: 0.7237
# Epoch 48/200
# 439/439 [==============================] - 18s 42ms/step - loss: 0.4878 - accuracy: 0.8228 - val_loss: 1.1828 - val_accuracy: 0.7207
# Epoch 49/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4818 - accuracy: 0.8296 - val_loss: 1.2100 - val_accuracy: 0.7217
# Epoch 50/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4877 - accuracy: 0.8301 - val_loss: 1.6421 - val_accuracy: 0.7377
# Epoch 51/200
# 439/439 [==============================] - 18s 42ms/step - loss: 0.4978 - accuracy: 0.8222 - val_loss: 1.3107 - val_accuracy: 0.7393
# Epoch 52/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4737 - accuracy: 0.8311 - val_loss: 1.1376 - val_accuracy: 0.7207
# Epoch 53/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4603 - accuracy: 0.8351 - val_loss: 1.2317 - val_accuracy: 0.7060
# Epoch 54/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4749 - accuracy: 0.8314 - val_loss: 1.2973 - val_accuracy: 0.7153
# Epoch 55/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4634 - accuracy: 0.8372 - val_loss: 1.3208 - val_accuracy: 0.7057
# Epoch 56/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4410 - accuracy: 0.8372 - val_loss: 1.3780 - val_accuracy: 0.7377
# Epoch 57/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4600 - accuracy: 0.8379 - val_loss: 1.1386 - val_accuracy: 0.7247
# Epoch 58/200
# 439/439 [==============================] - 18s 42ms/step - loss: 0.4587 - accuracy: 0.8366 - val_loss: 1.4728 - val_accuracy: 0.7197
# Epoch 59/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4952 - accuracy: 0.8269 - val_loss: 1.1665 - val_accuracy: 0.7247
# Epoch 60/200
# 439/439 [==============================] - 18s 42ms/step - loss: 0.4569 - accuracy: 0.8396 - val_loss: 1.3641 - val_accuracy: 0.7297
# Epoch 61/200
# 439/439 [==============================] - 18s 41ms/step - loss: 0.4718 - accuracy: 0.8385 - val_loss: 1.5251 - val_accuracy: 0.7257

# %%
model2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_2 (Conv2D)           (None, 198, 198, 32)      896
#
#  max_pooling2d_2 (MaxPooling  (None, 99, 99, 32)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 97, 97, 64)        18496
#
#  max_pooling2d_3 (MaxPooling  (None, 48, 48, 64)       0
#  2D)
#
#  batch_normalization (BatchN  (None, 48, 48, 64)       256
#  ormalization)
#
#  flatten_1 (Flatten)         (None, 147456)            0
#
#  dropout (Dropout)           (None, 147456)            0
#
#  dense_3 (Dense)             (None, 64)                9437248
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  dropout_2 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 16)                528
#
#  dropout_3 (Dropout)         (None, 16)                0
#
#  dense_6 (Dense)             (None, 6)                 102
#
# =================================================================
# Total params: 9,459,606
# Trainable params: 9,459,478
# Non-trainable params: 128
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt

acc2 = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss2 = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc2)+1)

plt.plot(epochs, acc2, 'b', label='Train Accuracy')
plt.plot(epochs, val_acc, 'r', label='Test Accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss2, 'b', label='Train Loss')
plt.plot(epochs, val_loss, 'r', label='Test Loss')
plt.legend()
plt.show()
